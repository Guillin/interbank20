# %% [markdown]
# # FEATURE IMPORTANCE

# %%
import pickle
import pandas as pd
import config
import matplotlib.pyplot as plt
from sklearn.tree import export_text,plot_tree
# %matplotlib inline

# %%
def load_model(modelname):

    # load the model from disk
    loaded_model = pickle.load(open(f"{config.MODEL_PATH}{modelname}.bin", 'rb'))

    return loaded_model

    pass

# %%
def get_features_name():
    # load datasets

    return list(pd.read_pickle(f"{config.INPUT_PATH}X_train.pkl").columns)

# %% [markdown]
# ### ID3

# %%
model = load_model("decision_tree_gini")

# %%
features = get_features_name()

# %%
feat_imp = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize=(20,6))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0, 0.5, 'Feature Importance Score')

# %%
r = tree.export_text(model,feature_names=features);

# %%
print(r)
# Out:
# |--- PRODUCTO_12_saldo__rolling_sum_t6 <= -5002.06
# |   |--- PRODUCTO_0_condicion_ <= 4.50
# |   |   |--- lon_x <= -1.89
# |   |   |   |--- condicion_std <= 0.75
# |   |   |   |   |--- PRODUCTO_1_saldo__diff_p3 <= -0.06
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- PRODUCTO_1_saldo__diff_p3 >  -0.06
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- condicion_std >  0.75
# |   |   |   |   |--- PRODUCTO_1_condicion_ <= 4.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- PRODUCTO_1_condicion_ >  4.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- lon_x >  -1.89
# |   |   |   |--- condicion_mean <= 0.02
# |   |   |   |   |--- PRODUCTO_0_saldo__count <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- PRODUCTO_0_saldo__count >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- condicion_mean >  0.02
# |   |   |   |   |--- PRODUCTO_11_condicion_ <= 6.50
# |   |   |   |   |   |--- class: 0
# ...

# %%
plt.figure(figsize=(10,10))
plot_tree(model,
           feature_names = features, 
           class_names='target',
           filled = True);

# %% [markdown]
# ### Random Forest

# %%
model = load_model("rf")

# %%
features = get_features_name()

# %%
feat_imp = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize=(20,6))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0, 0.5, 'Feature Importance Score')

# %% [markdown]
# ### XGBOOST

# %%
model = load_model("xgb")

# %%
features = get_features_name()

# %%
feat_imp = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize=(20,6))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0, 0.5, 'Feature Importance Score')

# %% [markdown]
# ### LightGBM

# %%
model = load_model("lgbm")

# %%
features = get_features_name()

# %%
feat_imp = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize=(20,6))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0, 0.5, 'Feature Importance Score')
