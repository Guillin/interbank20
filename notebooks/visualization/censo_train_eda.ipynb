# %% [markdown]
# # CENSO
# **censo_[train|test].csv**: información censal
#
# + lon_x: Coordenada X (Georreferenciación).
# + lat_y: Coordenada Y (Georreferenciación).
# + zon_sis: El registro se encuentra en una zona sísmica de intensidad 1, 2, 3, 4, 5 / 0= no hay data (Capas temáticas).
# + zon_der: 1 = El registro se encuentra en una zona de derrumbes o deslizamientos / 0= El registro no se encuentra en una zona de derrumbes o deslizamiento (Capas temáticas).
# + zon_inu: 1 = El registro se encuentra en una zona de inundación / 0= El registro no se encuentra en una zona de inundación (Capas temáticas).
# + zon_com: 1 = El registro se encuentra en una zona comercial / 0=El registro no se encuentra en una zona comercial (Capas temáticas).
# + pob: Cantidad de personas por manzana dentro de la manzana al año 2020 (Proyección).
# + pob_a: Cantidad de personas del nivel socioeconómico A dentro de la manzana al año 2020 (Proyección).
# + pob_b: Cantidad de personas del nivel socioeconómico B dentro de la manzana al año 2020 (Proyección).
# + pob_c: Cantidad de personas del nivel socioeconómico C dentro de la manzana al año 2020 (Proyección).
# + pob_d: Cantidad de personas del nivel socioeconómico D dentro de la manzana al año 2020 (Proyección).
# + pob_e: Cantidad de personas del nivel socioeconómico E dentro de la manzana al año 2020 (Proyección).
# + hog: Cantidad de hogares por manzana dentro de la manzana al año 2020 (Proyección).
# + a: Cantidad de hogares del nivel socioeconómico A dentro de la manzana al año 2020 (Proyección).
# + b: Cantidad de hogares del nivel socioeconómico B dentro de la manzana al año 2020 (Proyección).
# + c: Cantidad de hogares del nivel socioeconómico C dentro de la manzana al año 2020 (Proyección).
# + d: Cantidad de hogares del nivel socioeconómico D dentro de la manzana al año 2020 (Proyección).
# + e: Cantidad de hogares del nivel socioeconómico E dentro de la manzana al año 2020 (Proyección).
# + pred: Nivel socioeconómico predominante en la manzana dentro de la manzana al año 2020 / NA: Manzana no le corresponde NSE (instituciones, parques, etc) / 0: missing para la base de datos de proyecciones (no ha enlazado con la mza, no se tiene información) (Proyección).
# + ing_a_18: Suma del ingreso promedio mensual del hogar para el NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_ali_a_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_ves_a_18: Suma de gasto promedio mensual del hogar Vestido y Calzado del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_alq_a_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_mue_a_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_sal_a_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_trans_a_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_esp_a_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza del NSE A dentro de la manzana al año 2018 (Proyección).
# + gas_otrs_a_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios del NSE A dentro de la manzana al año 2018 (Proyección).
# + ing_b_18: Suma del ingreso promedio mensual del hogar para el NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_ali_b_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_ves_b_18: Suma de gasto promedio mensual del hogar Vestido y Calzado del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_alq_b_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_mue_b_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_sal_b_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_trans_b_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_esp_b_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza del NSE B dentro de la manzana al año 2018 (Proyección).
# + gas_otrs_b_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios del NSE B dentro de la manzana al año 2018 (Proyección).
# + ing_c_18: Suma del ingreso promedio mensual del hogar para el NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_ali_c_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_ves_c_18: Suma de gasto promedio mensual del hogar Vestido y Calzado del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_alq_c_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_mue_c_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_sal_c_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_trans_c_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_esp_c_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza del NSE C dentro de la manzana al año 2018 (Proyección).
# + gas_otrs_c_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios del NSE C dentro de la manzana al año 2018 (Proyección).
# + ing_d_18: Suma del ingreso promedio mensual del hogar para el NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_ali_d_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_ves_d_18: Suma de gasto promedio mensual del hogar Vestido y Calzado del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_alq_d_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_mue_d_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_sal_d_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_trans_d_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_esp_d_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza del NSE D dentro de la manzana al año 2018 (Proyección).
# + gas_otrs_d_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios del NSE D dentro de la manzana al año 2018 (Proyección).
# + ing_e_18: Suma del ingreso promedio mensual del hogar para el NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_ali_e_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_ves_e_18: Suma de gasto promedio mensual del hogar Vestido y Calzado del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_alq_e_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_mue_e_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_sal_e_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_trans_e_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_esp_e_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza del NSE E dentro de la manzana al año 2018 (Proyección).
# + gas_otrs_e_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios del NSE E dentro de la manzana al año 2018 (Proyección).
# + ing_18: Suma del ingreso promedio mensual del hogar dentro de la manzana al año 2018 (Proyección).
# + g1_18: Suma de gasto promedio mensual del hogar en Alimentos y Bebidas dentro de la manzana al año 2018 (Proyección).
# + g2_18: Suma de gasto promedio mensual del hogar Vestido y Calzado dentro de la manzana al año 2018 (Proyección).
# + g3_18: Suma de gasto promedio mensual del hogar en Alquiler de Vivienda, Combustible, Electricidad y Conservación de la Vivienda dentro de la manzana al año 2018 (Proyección).
# + g4_18: Suma de gasto promedio mensual del hogar en Muebles, Enseres y Mantenimiento de la Vivienda del dentro de la manzana al año 2018 (Proyección).
# + g5_18: Suma de gasto promedio mensual del hogar en Cuidado, Conservación de la Salud y Servicios Médicos dentro de la manzana al año 2018 (Proyección).
# + g6_18: Suma de gasto promedio mensual del hogar en Transporte y Comunicaciones dentro de la manzana al año 2018 (Proyección).
# + g7_18: Suma de gasto promedio mensual del hogar en Esparcimiento, Diversión, Servicio, Cultura y de Enseñanza dentro de la manzana al año 2018 (Proyección).
# + g8_18: Suma de gasto promedio mensual del hogar en Otros Bienes y Servicios dentro de la manzana al año 2018 (Proyección).
# + viviendas: Cantidad de viviendas en la manzana (Censo 2017).
# + nhogares: Cantidad total de hogares en viviendas particulares (Censo 2017).
# + dehogar1: Cantidad de viviendas con 1 hogar (Censo 2017).
# + dehogar2: Cantidad de viviendas con 2 hogares (Censo 2017).
# + dehogar3: Cantidad de viviendas con 3 hogares (Censo 2017).
# + dehogar4: Cantidad de viviendas con 4 hogares (Censo 2017).
# + dehogar5: Cantidad de viviendas con 5 hogares (Censo 2017).
# + dehogar6: Cantidad de viviendas con 6 hogares (Censo 2017).
# + dehogar7: Cantidad de viviendas con 7 hogares (Censo 2017).
# + dehogar8: Cantidad de viviendas con 8 hogares (Censo 2017).
# + tipviv1: Cantidad de viviendas cuyo tipo es de casa independiente (Censo 2017).
# + tipviv2: Cantidad de viviendas cuyo tipo es de departamento en edificio (Censo 2017).
# + tipviv3: Cantidad de viviendas cuyo tipo es de vivienda en quinta (Censo 2017).
# + tipviv4: Cantidad de viviendas cuyo tipo es de vivienda en casa de vecindad (callejón, solar o corralón) (Censo 2017).
# + tipviv6: Cantidad de viviendas cuyo tipo es de vivienda improvisada (Censo 2017).
# + tipviv7: Cantidad de viviendas cuyo tipo es de local no destinado para habitación humana (Censo 2017).
# + tipviv9: Cantidad de viviendas cuyo tipo es de viviendas colectivas (Censo 2017).
# + matpar1: Cantidad de viviendas con material de construcción en las paredes de tipo ladrillo o bloque de cemento (Censo 2017).
# + matpar2: Cantidad de viviendas con material de construcción en las paredes de tipo piedra o sillar con cal o cemento (Censo 2017).
# + matpar3: Cantidad de viviendas con material de construcción en las paredes de tipo adobe (Censo 2017).
# + matpar4: Cantidad de viviendas con material de construcción en las paredes de tipo tapia (Censo 2017).
# + matpar5: Cantidad de viviendas con material de construcción en las paredes de tipo quincha (caña con barro) (Censo 2017).
# + matpar6: Cantidad de viviendas con material de construcción en las paredes de tipo piedra con barro (Censo 2017).
# + matpar7: Cantidad de viviendas con material de construcción en las paredes de tipo madera (pona, tornillo etc.) (Censo 2017).
# + matpar8: Cantidad de viviendas con material de construcción en las paredes de tipo triplay / calamina / estera (Censo 2017).
# + matpis1: Cantidad de viviendas con material de construcción en los pisos de tipo parquet o madera pulida (Censo 2017).
# + matpis2: Cantidad de viviendas con material de construcción en los pisos de tipo láminas asfálticas, vinílicos o similares (Censo 2017).
# + matpis3: Cantidad de viviendas con material de construcción en los pisos de tipo losetas, terrazos, cerámicos o similares (Censo 2017).
# + matpis4: Cantidad de viviendas con material de construcción en los pisos de tipo madera (pona, tornillo, etc.) (Censo 2017).
# + matpis5: Cantidad de viviendas con material de construcción en los pisos de tipo cemento (Censo 2017).
# + matpis6: Cantidad de viviendas con material de construcción en los pisos de tipo tierra (Censo 2017).
# + matpis7: Cantidad de viviendas con material de construcción en los pisos de tipo otro material (Censo 2017).
# + abaagu1: Cantidad de viviendas cuyo abastecimiento en agua procede de red pública dentro de la vivienda (Censo 2017).
# + abaagu2: Cantidad de viviendas cuyo abastecimiento en agua procede de red pública fuera de la vivienda, pero dentro de la edificación (Censo 2017).
# + abaagu3: Cantidad de viviendas cuyo abastecimiento en agua procede de pilón o pileta de uso público (Censo 2017).
# + abaagu4: Cantidad de viviendas cuyo abastecimiento en agua procede de camión - cisterna u otro similar (Censo 2017).
# + abaagu5: Cantidad de viviendas cuyo abastecimiento en agua procede de pozo (agua subterránea) (Censo 2017).
# + abaagu6: Cantidad de viviendas cuyo abastecimiento en agua procede de manantial o puquio (Censo 2017).
# + abaagu7: Cantidad de viviendas cuyo abastecimiento en agua procede de río, acequia, lago, laguna (Censo 2017).
# + abaagu8: Cantidad de viviendas cuyo abastecimiento en agua procede de otro (Censo 2017).
# + abaagu9: Cantidad de viviendas cuyo abastecimiento en agua procede de vecino (Censo 2017).
# + vivten1: Cantidad de viviendas de tipo alquilada (Censo 2017).
# + vivten2: Cantidad de viviendas de tipo propia sin título de propiedad (Censo 2017).
# + vivten3: Cantidad de viviendas de tipo propia con título de propiedad (Censo 2017).
# + vivten4: Cantidad de viviendas de tipo cedida (Censo 2017).
# + vivten5: Cantidad de viviendas de otro tipo (Censo 2017).
# + totper: Cantidad de personas (Censo 2017).
# + mattec1: Cantidad de viviendas con material de construcción en los techos de tipo concreto armado (Censo 2017).
# + mattec2: Cantidad de viviendas con material de construcción en los techos de tipo madera (Censo 2017).
# + mattec3: Cantidad de viviendas con material de construcción en los techos de tipo tejas (Censo 2017).
# + mattec4: Cantidad de viviendas con material de construcción en los techos de tipo planchas de calamina, fibra de cemento o similares (Censo 2017).
# + mattec5: Cantidad de viviendas con material de construcción en los techos de tipo caña o estera con torta de barro o cemento (Censo 2017).
# + mattec6: Cantidad de viviendas con material de construcción en los techos de tipo triplay / estera / carrizo (Censo 2017).
# + mattec7: Cantidad de viviendas con material de construcción en los techos de tipo paja, hoja de palmera y similares (Censo 2017).
# + mattec8: Cantidad de viviendas con material de construcción en los techos de tipo otro material (Censo 2017).
# + agudia1: Cantidad de viviendas que posee servicio de agua todos los días de la semana (Censo 2017).
# + agudia2: Cantidad de viviendas que posee servicio de agua solo algunos los días de la semana (Censo 2017).
# + agundia1: Cantidad de viviendas que tiene servicio de agua solo 1 día a la semana (Censo 2017).
# + agundia2: Cantidad de viviendas que tiene servicio de agua solo 2 días a la semana (Censo 2017).
# + agundia3: Cantidad de viviendas que tiene servicio de agua solo 3 días a la semana (Censo 2017).
# + agundia4: Cantidad de viviendas que tiene servicio de agua solo 4 días a la semana (Censo 2017).
# + agundia5: Cantidad de viviendas que tiene servicio de agua solo 5 días a la semana (Censo 2017).
# + agundia6: Cantidad de viviendas que tiene servicio de agua solo 6 días a la semana (Censo 2017).
# + pagagusi: Cantidad de viviendas que si pagan por el servicio de agua (Censo 2017).
# + pagaguno: Cantidad de viviendas que no pagan por el servicio de agua (Censo 2017).
# + pagagu1: Cantidad de viviendas que pagan a una empresa prestadora de servicios (eps-seda-emapa) por el servicio de agua (Censo 2017).
# + pagagu2: Cantidad de viviendas que pagan a la municipalidad por el servicio de agua (Censo 2017).
# + pagagu3: Cantidad de viviendas que pagan a una organización comunal por el servicio de agua (Censo 2017).
# + pagagu4: Cantidad de viviendas que pagan a un camión cisterna (pago directo) por el servicio de agua (Censo 2017).
# + pagagu5: Cantidad de viviendas que pagan a un vecino por el servicio de agua (Censo 2017).
# + hig1: Cantidad de viviendas con servicio higiénico conectado a la red pública de desagüe dentro de la vivienda (Censo 2017).
# + hig2: Cantidad de viviendas con servicio higiénico conectado a la red pública de desagüe fuera de la vivienda, pero dentro de la edificación (Censo 2017).
# + hig3: Cantidad de viviendas con servicio higiénico conectado a un pozo séptico, tanque séptico o biodigestor (Censo 2017).
# + hig4: Cantidad de viviendas con servicio higiénico conectado a una letrina (con tratamiento) (Censo 2017).
# + hig5: Cantidad de viviendas con servicio higiénico conectado a un pozo ciego o negro (Censo 2017).
# + hig6: Cantidad de viviendas con servicio higiénico conectado a un río, acequia, canal o similar (Censo 2017).
# + hig7: Cantidad de viviendas con servicio higiénico conectado a un campo abierto o al aire libre (Censo 2017).
# + hig8: Cantidad de viviendas con servicio higiénico conectado a otro (Censo 2017).
# + alupusi: Cantidad de viviendas que tienen alumbrado eléctrico por red pública (Censo 2017).
# + alupuno: Cantidad de viviendas que no tienen alumbrado eléctrico por red pública (Censo 2017).
# + equiten: Cantidad de hogares que poseen equipo de sonido (Censo 2017).
# + equiteno: Cantidad de hogares que no poseen equipo de sonido (Censo 2017).
# + tvten: Cantidad de hogares que poseen televisor a color (Censo 2017).
# + tvteno: Cantidad de hogares que no poseen televisor a color (Censo 2017).
# + cocten: Cantidad de hogares que poseen cocina a gas (Censo 2017).
# + cocteno: Cantidad de hogares que no poseen cocina a gas (Censo 2017).
# + reften: Cantidad de hogares que poseen refrigeradora o congeladora (Censo 2017).
# + refteno: Cantidad de hogares que no poseen refrigeradora o congeladora (Censo 2017).
# + lavten: Cantidad de hogares que poseen lavadora de ropa (Censo 2017).
# + lavteno: Cantidad de hogares que no poseen lavadora de ropa (Censo 2017).
# + horten: Cantidad de hogares que poseen horno microondas (Censo 2017).
# + horteno: Cantidad de hogares que no poseen horno microondas (Censo 2017).
# + licten: Cantidad de hogares que poseen licuadora (Censo 2017).
# + licteno: Cantidad de hogares que no poseen licuadora (Censo 2017).
# + platen: Cantidad de hogares que poseen plancha eléctrica (Censo 2017).
# + plateno: Cantidad de hogares que no poseen plancha eléctrica (Censo 2017).
# + compten: Cantidad de hogares que poseen computadora/laptop/tablet (Censo 2017).
# + compteno: Cantidad de hogares que no poseen computadora/laptop/tablet (Censo 2017).
# + celten: Cantidad de hogares que poseen el servicio de teléfono celular (Censo 2017).
# + celteno: Cantidad de hogares que no poseen el servicio de teléfono celular (Censo 2017).
# + tefijten: Cantidad de hogares que poseen el servicio de teléfono fijo (Censo 2017).
# + tefijteno: Cantidad de hogares que no poseen el servicio de teléfono fijo (Censo 2017).
# + cabten: Cantidad de hogares que poseen el servicio de conexión a tv por cable o satelital (Censo 2017).
# + cabteno: Cantidad de hogares que no poseen el servicio de conexión a tv por cable o satelital (Censo 2017).
# + intten: Cantidad de hogares que poseen el servicio de conexión a internet (Censo 2017).
# + intteno: Cantidad de hogares que poseen el servicio de conexión a internet (Censo 2017).
# + autten: Cantidad de hogares que poseen automóvil, camioneta (Censo 2017).
# + autteno: Cantidad de hogares que no poseen automóvil, camioneta (Censo 2017).
# + motten: Cantidad de hogares que poseen tiene motocicleta (Censo 2017).
# + motteno: Cantidad de hogares que no poseen motocicleta (Censo 2017).
# + lanten: Cantidad de hogares que poseen lancha, bote motor o peque peque, canoa (Censo 2017).
# + lanteno: Cantidad de hogares que no poseen lancha, bote motor o peque peque, canoa (Censo 2017).
# + inf: Cantidad de personas en su primera infancia (0 - 5 años) (Censo 2017).
# + nin: Cantidad de personas en su niñez (6 - 11 años) (Censo 2017).
# + ado: Cantidad de personas en su adolescencia (12 - 17 años) (Censo 2017).
# + jov: Cantidad de personas jóvenes (18 - 29 años) (Censo 2017).
# + adujov: Cantidad de personas adultos/as jóvenes (30 - 44 años) (Censo 2017).
# + adu: Cantidad de personas adultos/as (45 - 59 años) (Censo 2017).
# + adumay: Cantidad de personas adultos/as mayores (60 y más años) (Censo 2017).
# + pafisis_no: Cantidad de personas que no está afiliado al SIS (Censo 2017).
# + pafisis: Cantidad de personas afiliada al SIS (Censo 2017).
# + paess_no: Cantidad de personas que no está afiliado a ESSALUD (Censo 2017).
# + paess: Cantidad de personas afiliada a ESSALUD (Censo 2017).
# + pafue_no: Cantidad de personas que no está afiliado al seguro de fuerzas armadas o policiales (Censo 2017).
# + pafue: Cantidad de personas afiliada al seguro de fuerzas armadas o policiales (Censo 2017).
# + papri_no: Cantidad de personas no está afiliado a seguro privado de salud (Censo 2017).
# + papri: Cantidad de personas afiliada a seguro privado de salud (Censo 2017).
# + paotr_no: Cantidad de personas que no está afiliado a otro seguro (Censo 2017).
# + paotr: Cantidad de personas afiliada a otro seguro (Censo 2017).
# + panin_no: Cantidad de personas afiliada a algún seguro (Censo 2017).
# + panin: Cantidad de personas que no se encuentra afiliado a ningún seguro (Censo 2017).
# + lee_si: Cantidad de personas que sabe leer y escribir (Censo 2017).
# + lee_no: Cantidad de personas que no sabe leer y escribir (Censo 2017).
# + estud_1: Cantidad de personas con último nivel de estudios que aprobó - sin nivel (Censo 2017).
# + estud_2: Cantidad de personas con último nivel de estudios que aprobó - inicial (Censo 2017).
# + estud_3: Cantidad de personas con último nivel de estudios que aprobó - primaria (Censo 2017).
# + estud_4: Cantidad de personas con último nivel de estudios que aprobó - secundaria (Censo 2017).
# + estud_5: Cantidad de personas con último nivel de estudios que aprobó - básica especial (Censo 2017).
# + estud_6: Cantidad de personas con último nivel de estudios que aprobó - superior no universitaria incompleta (Censo 2017).
# + estud_7: Cantidad de personas con último nivel de estudios que aprobó - superior no universitaria completa (Censo 2017).
# + estud_8: Cantidad de personas con último nivel de estudios que aprobó - superior universitaria incompleta (Censo 2017).
# + estud_9: Cantidad de personas con último nivel de estudios que aprobó - superior universitaria completa (Censo 2017).
# + estud_10: Cantidad de personas con último nivel de estudios que aprobó - maestría / doctorado (Censo 2017).
# + profe_1: Cantidad de personas con ocupación principal agrupado según - miembros del poder ejecutivo, legislativo, judicial y personal directivo de la administración pública y privada (Censo 2017).
# + profe_2: Cantidad de personas con ocupación principal agrupado según - profesionales científicos e intelectuales (Censo 2017).
# + profe_3: Cantidad de personas con ocupación principal agrupado según - profesionales técnicos (Censo 2017).
# + profe_4: Cantidad de personas con ocupación principal agrupado según - jefes y empleados administrativos (Censo 2017).
# + profe_5: Cantidad de personas con ocupación principal agrupado según - trabajadores de los servicios y vendedores de comercios y mercados (Censo 2017).
# + profe_6: Cantidad de personas con ocupación principal agrupado según - agricultores y trabajadores calificados agropecuarios, forestales y pesqueros (Censo 2017).
# + profe_7: Cantidad de personas con ocupación principal agrupado según - trabajadores de la construcción, edificación, productos artesanales, electricidad y las telecomunicaciones (Censo 2017).
# + profe_8: Cantidad de personas con ocupación principal agrupado según - operadores de maquinaria industrial, ensambladores y conductores de transporte (Censo 2017).
# + profe_9: Cantidad de personas con ocupación principal agrupado según - ocupaciones elementales (Censo 2017).
# + profe_10: Cantidad de personas con ocupación principal agrupado según - ocupaciones (Censo 2017).
# + acteco1: Cantidad de personas con actividad economica a la que se dedica según - a. agricultura, ganadería, silvicultura y pesca (Censo 2017).
# + acteco2: Cantidad de personas con actividad economica a la que se dedica según - b. explotación de minas y canteras (Censo 2017).
# + acteco3: Cantidad de personas con actividad economica a la que se dedica según - c. industrias manufactureras (Censo 2017).
# + acteco4: Cantidad de personas con actividad economica a la que se dedica según - d. suministro de electricidad, gas, vapor y aire acondicionado (Censo 2017).
# + acteco5: Cantidad de personas con actividad economica a la que se dedica según - e. suministro de agua; evacuación de aguas residuales, gestión de desechos y descontaminación (Censo 2017).
# + acteco6: Cantidad de personas con actividad economica a la que se dedica según - f. construcción (Censo 2017).
# + acteco7: Cantidad de personas con actividad economica a la que se dedica según - g. comercio al por mayor y al por menor; reparación de vehículos automotores y motocicletas (Censo 2017).
# + acteco8: Cantidad de personas con actividad economica a la que se dedica según - h. transporte y almacenamiento (Censo 2017).
# + acteco9: Cantidad de personas con actividad economica a la que se dedica según - i. actividades de alojamiento y de servicio de comidas (Censo 2017).
# + acteco10: Cantidad de personas con actividad economica a la que se dedica según - j. información y comunicaciones (Censo 2017).
# + acteco11: Cantidad de personas con actividad economica a la que se dedica según - k. actividades financieras y de seguros (Censo 2017).
# + acteco12: Cantidad de personas con actividad economica a la que se dedica según - l. actividades inmobiliarias (Censo 2017).
# + acteco13: Cantidad de personas con actividad economica a la que se dedica según - m. actividades profesionales, científicas y técnicas (Censo 2017).
# + acteco14: Cantidad de personas con actividad economica a la que se dedica según - n. actividades de servicios administrativos y de apoyo (Censo 2017).
# + acteco15: Cantidad de personas con actividad economica a la que se dedica según - o. administración pública y defensa; planes de seguridad social de afiliación obligatoria (Censo 2017).
# + acteco16: Cantidad de personas con actividad economica a la que se dedica según - p. enseñanza (Censo 2017).
# + acteco17: Cantidad de personas con actividad economica a la que se dedica según - q. actividades de atención de la salud humana y de asistencia social (Censo 2017).
# + acteco18: Cantidad de personas con actividad economica a la que se dedica según - r. actividades artísticas, de entretenimiento y recreativas (Censo 2017).
# + acteco19: Cantidad de personas con actividad economica a la que se dedica según - s. otras actividades de servicios (Censo 2017).
# + acteco20: Cantidad de personas con actividad economica a la que se dedica según - t. actividades de los hogares como empleadores; actividades no diferenciadas de los hogares como productores de bienes y servicios para uso propio (Censo 2017).
# + acteco21: Cantidad de personas con actividad economica a la que se dedica según - u. actividades de organizaciones y órganos extraterritoriales (Censo 2017).
# + ocup_1: Cantidad de personas que en su trabajo se desempeño como - empleador(a) o patrono(a) (Censo 2017).
# + ocup_2: Cantidad de personas que en su trabajo se desempeño como - trabajador(a) independiente o por cuenta propia (Censo 2017).
# + ocup_3: Cantidad de personas que en su trabajo se desempeño como - empleado(a) (Censo 2017).
# + ocup_4: Cantidad de personas que en su trabajo se desempeño como - obrero(a) (Censo 2017).
# + ocup_5: Cantidad de personas que en su trabajo se desempeño como - trabajador(a) en negocio de un familiar (Censo 2017).
# + ocup_6: Cantidad de personas que en su trabajo se desempeño como - trabajador(a) del hogar (Censo 2017).
# + flag_censo: sin datos: No hay datos en la base censo 2017 con datos: Si hay datos en la base censo 2017 (Censo 2017).

# %%
import pandas as pd
import pickle as pickle
import numpy as np
from datetime import datetime
from datetime import date
from scipy import stats
# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import warnings; warnings.simplefilter('ignore')
import seaborn as sns
import os
import gc
from ipyleaflet import Map, Marker
pd.set_option('display.max_columns', None)

# %%
# Background graph style
sns.set(style="darkgrid")
# ==============
# Chouse color
# ==============
sns.palplot(sns.color_palette("Set2"))  # show color
sns.set_palette("Set2") # for seaborn
colors = sns.color_palette("Set2") # for pyplot

# %%
def reduce_mem_usage(df, verbose=False):
    start_mem = df.memory_usage().sum() / 1024 ** 2
    int_columns = df.select_dtypes(include=["int"]).columns
    float_columns = df.select_dtypes(include=["float"]).columns

    for col in int_columns:
        df[col] = pd.to_numeric(df[col], downcast="integer")

    for col in float_columns:
        df[col] = pd.to_numeric(df[col], downcast="float")

    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

for dirname, _, filenames in os.walk('../../data/raw/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../../data/raw/productos.csv
# ../../data/raw/censo_train.csv
# ../../data/raw/censo_test.csv
# ../../data/raw/y_train.csv
# ../../data/raw/sample_submission.csv
# ../../data/raw/sunat_train.csv
# ../../data/raw/se_train.csv
# ../../data/raw/se_test.csv
# ../../data/raw/rcc_test.csv
# ../../data/raw/rcc_train.csv
# ../../data/raw/interbank20.zip
# ../../data/raw/sunat_test.csv

# %%
censo = pd.read_csv("../../data/raw/censo_train.csv").pipe(reduce_mem_usage)

# %%
censo.shape
# Out:
# (153139, 256)

# %%
censo.head()
# Out:
#    key_value     lon_x     lat_y   zon_sis   zon_der  zon_inu   zon_com  \
# 0     106695  1.827118 -0.711359 -0.931515 -0.242328 -0.32701 -0.280674
# 1     271120 -0.480514  0.198531  0.054361 -0.242328 -0.32701 -0.280674
# 2      63080 -0.192205 -0.216570  1.040236 -0.242328 -0.32701 -0.280674
# 3     107681 -0.803171  0.748640  1.040236 -0.242328 -0.32701 -0.280674
# 4     107336  1.983624 -1.649749 -0.931515 -0.242328 -0.32701 -0.280674
#
#       score       pob     pob_a     pob_b     pob_c     pob_d     pob_e  \
# 0 -0.714361 -0.544996 -0.312923 -0.425825 -0.565415 -0.089094 -0.165019
# 1 -0.104283 -0.060420 -0.312923 -0.485131  0.448644 -0.059923 -0.308719
# 2 -0.124272  0.607510 -0.312923  1.092421 -0.230260  0.961048  0.733106
# 3 -0.540244 -0.658501 -0.131975 -0.437686 -0.599790 -0.439141 -0.308719
# 4 -0.104283 -0.470782  0.669365  0.048627 -0.694321 -0.643335 -0.452419
#
#         hog         a         b         c         d         e  pred  ing_a_18  \
# ...

# %%
censo.describe()
# Out:
#            key_value         lon_x         lat_y       zon_sis       zon_der  \
# count  153139.000000  1.531390e+05  1.531390e+05  1.531390e+05  1.531390e+05
# mean   174702.449578  4.607577e-09 -3.030461e-09 -2.426377e-07  4.951628e-08
# std    102022.367281  1.000012e+00  9.999909e-01  9.999833e-01  1.001015e+00
# min         0.000000 -1.890810e+00 -2.207389e+00 -9.315150e-01 -2.423285e-01
# 25%     86104.500000 -2.217318e-01 -2.597481e-01 -9.315150e-01 -2.423285e-01
# 50%    174023.000000 -1.861968e-01 -2.253812e-01  5.436064e-02 -2.423285e-01
# 75%    261980.000000 -5.238179e-02  1.345394e-01  1.040236e+00 -2.423285e-01
# max    358438.000000  2.977504e+00  2.587176e+00  3.997863e+00  4.126630e+00
#
#             zon_inu        zon_com         score           pob         pob_a  \
# count  1.531390e+05  153139.000000  1.531390e+05  1.531390e+05  1.531390e+05
# mean  -4.553811e-07       0.000001  5.028602e-07 -1.629320e-08  2.446428e-07
# ...

# %% [markdown]
# ### lon_x

# %%
plt.figure(figsize=(8, 2))
ax = sns.boxplot(y="lon_x", orient="h", linewidth=1.5, data=censo) # DataFrame, array, or list of arrays, optional
ax.set_title("BoxPlot dist lon_x - TRAIN")
ax.yaxis.grid(True)
pass

# %% [markdown]
# ### lat_y

# %%
plt.figure(figsize=(8, 2))
ax = sns.boxplot(y="lat_y", orient="h", linewidth=1.5, data=censo) # DataFrame, array, or list of arrays, optional
ax.set_title("BoxPlot dist lat_y - TRAIN")
ax.yaxis.grid(True)
pass

# %%
censo_cordsample = censo_train.sample(100).loc[:,['lon_x','lat_y']]

# %%
center=(-9.78077,-75.2334557)
m = Map(center=(-9.78077,-75.2334557), zoom=5)
for x,y in zip(censo_cordsample.lon_x,censo_cordsample.lat_y):
    marker = Marker(location=(x,y), draggable=False)
    m.add_layer(marker);

m
# Out:
# Map(center=[-9.78077, -75.2334557], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ### zon_sis
# El registro se encuentra en una zona sísmica de intensidad 1, 2, 3, 4, 5 / 0= no hay data (Capas temáticas).

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x="zon_sis",linewidth=1.5, data=censo, order=censo.zon_sis.unique().tolist().sort()).set_title("Num reg by zon_sis - TRAIN")
pass

# %% [markdown]
# ### zon_der
# 1 = El registro se encuentra en una zona de derrumbes o deslizamientos / 0= El registro no se encuentra en una zona de derrumbes o deslizamiento (Capas temáticas).

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x="zon_der",linewidth=1.5, data=censo, order=censo.zon_der.unique().tolist().sort()).set_title("Num reg by zon_der - TRAIN")
pass

# %% [markdown]
# ### zon_inu
# 1 = El registro se encuentra en una zona de inundación / 0= El registro no se encuentra en una zona de inundación (Capas temáticas).

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x="zon_inu",linewidth=1.5, data=censo, order=censo.zon_inu.unique().tolist().sort()).set_title("Num reg by zon_inu - TRAIN")
pass

# %% [markdown]
# ### zon_com
# 1 = El registro se encuentra en una zona comercial / 0=El registro no se encuentra en una zona comercial (Capas temáticas).

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x="zon_com",linewidth=1.5, data=censo).set_title("Num reg by zon_com - TRAIN")
pass

# %% [markdown]
# ### poblacion
# + pob: Cantidad de personas por manzana dentro de la manzana al año 2020 (Proyección).
# + pob_a: Cantidad de personas del nivel socioeconómico A dentro de la manzana al año 2020 (Proyección).
# + pob_b: Cantidad de personas del nivel socioeconómico B dentro de la manzana al año 2020 (Proyección).
# + pob_c: Cantidad de personas del nivel socioeconómico C dentro de la manzana al año 2020 (Proyección).
# + pob_d: Cantidad de personas del nivel socioeconómico D dentro de la manzana al año 2020 (Proyección).
# + pob_e: Cantidad de personas del nivel socioeconómico E dentro de la manzana al año 2020 (Proyección).

# %%
pobdf = censo.melt(id_vars=['key_value'], value_vars=['pob','pob_a', 'pob_b','pob_c','pob_d','pob_e'],
          var_name='poblacion', value_name='cantidad_personas')

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y="cantidad_personas", x="poblacion",  linewidth=1.2, data=pobdf) # DataFrame, array, or list of arrays, optional
ax.set_title("BoxPlot dist poblacion - TRAIN")
ax.yaxis.grid(True)
pass

# %% [markdown]
# ### Hogares
# + hog: Cantidad de hogares por manzana dentro de la manzana al año 2020 (Proyección).
# + a: Cantidad de hogares del nivel socioeconómico A dentro de la manzana al año 2020 (Proyección).
# + b: Cantidad de hogares del nivel socioeconómico B dentro de la manzana al año 2020 (Proyección).
# + c: Cantidad de hogares del nivel socioeconómico C dentro de la manzana al año 2020 (Proyección).
# + d: Cantidad de hogares del nivel socioeconómico D dentro de la manzana al año 2020 (Proyección).
# + e: Cantidad de hogares del nivel socioeconómico E dentro de la manzana al año 2020 (Proyección).

# %%
hogdf = censo.melt(id_vars=['key_value'], value_vars=['hog', 'a', 'b', 'c', 'd', 'e'],
          var_name='hogares', value_name='cantidad_personas')

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y="cantidad_personas", x="hogares",  linewidth=1.2, data=hogdf) # DataFrame, array, or list of arrays, optional
ax.set_title("BoxPlot dist poblacion - TRAIN")
ax.yaxis.grid(True)
pass
